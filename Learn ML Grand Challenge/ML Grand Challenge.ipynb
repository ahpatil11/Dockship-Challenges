# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('new_train.csv')
train.head()
# Out:
#          Date  Open-Stock-1  High-Stock-1  Low-Stock-1  Close-Stock-1  \
# 0  2010-06-01        1889.7       1890.00      1838.00        1855.10
# 1  2010-06-02        1848.0       1862.75      1828.00        1853.05
# 2  2010-06-03        1864.1       1910.00      1864.10        1905.60
# 3  2010-06-04        1906.0       1909.80      1880.10        1885.70
# 4  2010-06-07        1867.0       1894.85      1808.35        1876.65
#
#    VWAP-Stock-1  Volume-Stock-1  Turnover-Stock-1  Open-Stock-2  High-Stock-2  \
# 0       1855.75          568273   105457457545000        285.40        285.95
# 1       1842.82          945167   174177161135000        284.00        284.80
# 2       1893.91          679689   128727119355000        283.00        286.85
# 3       1889.21          509435    96242800140000        288.85        291.80
# 4       1873.32          961913   180196832650000        285.00        289.10
#
#    ...  VWAP-Stock-4  Volume-Stock-4  Turnover-Stock-4  Open-Stock-5  \
# ...

# %%
train.shape
# Out:
# (299, 36)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 36 columns):
# Date                299 non-null object
# Open-Stock-1        299 non-null float64
# High-Stock-1        299 non-null float64
# Low-Stock-1         299 non-null float64
# Close-Stock-1       299 non-null float64
# VWAP-Stock-1        299 non-null float64
# Volume-Stock-1      299 non-null int64
# Turnover-Stock-1    299 non-null int64
# Open-Stock-2        299 non-null float64
# High-Stock-2        299 non-null float64
# Low-Stock-2         299 non-null float64
# Close-Stock-2       299 non-null float64
# VWAP-Stock-2        299 non-null float64
# Volume-Stock-2      299 non-null int64
# Turnover-Stock-2    299 non-null int64
# Open-Stock-3        299 non-null float64
# High-Stock-3        299 non-null float64
# Low-Stock-3         299 non-null float64
# Close-Stock-3       299 non-null float64
# VWAP-Stock-3        299 non-null float64
# ...

# %%
test = pd.read_csv('new_test.csv')
test.head()
# Out:
#          Date  Open-Stock-1  High-Stock-1  Low-Stock-1  VWAP-Stock-1  \
# 0  2011-08-04         484.1        488.90       475.00        481.00
# 1  2011-08-05         465.0        475.80       457.10        469.56
# 2  2011-08-08         463.0        480.00       458.05        465.04
# 3  2011-08-09         450.0        473.55       449.85        460.88
# 4  2011-08-10         494.8        494.80       473.40        478.06
#
#    Volume-Stock-1  Turnover-Stock-1  Open-Stock-2  High-Stock-2  Low-Stock-2  \
# 0         1829606    88003633160000        204.90        206.75       199.20
# 1         3156094   148196817355000        195.00        198.00       190.50
# 2         4308373   200357861965000        193.90        197.80       189.65
# 3         4490924   206978212685000        190.25        202.10       190.10
# 4         3267226   156192368225000        202.00        202.85       196.00
#
#    ...  Low-Stock-4  VWAP-Stock-4  Volume-Stock-4  Turnover-Stock-4  \
# ...

# %%
test.shape
# Out:
# (97, 31)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 31 columns):
# Date                97 non-null object
# Open-Stock-1        97 non-null float64
# High-Stock-1        97 non-null float64
# Low-Stock-1         97 non-null float64
# VWAP-Stock-1        97 non-null float64
# Volume-Stock-1      97 non-null int64
# Turnover-Stock-1    97 non-null int64
# Open-Stock-2        97 non-null float64
# High-Stock-2        97 non-null float64
# Low-Stock-2         97 non-null float64
# VWAP-Stock-2        97 non-null float64
# Volume-Stock-2      97 non-null int64
# Turnover-Stock-2    97 non-null int64
# Open-Stock-3        97 non-null float64
# High-Stock-3        97 non-null float64
# Low-Stock-3         97 non-null float64
# VWAP-Stock-3        97 non-null float64
# Volume-Stock-3      97 non-null int64
# Turnover-Stock-3    97 non-null int64
# Open-Stock-4        97 non-null float64
# High-Stock-4        97 non-null float64
# ...

# %%
newtrain = train
newtest = test

# %%
newtrain = newtrain.drop('Date', axis = 1)
newtest = newtest.drop('Date', axis = 1)

# %%
newtrain.shape
# Out:
# (299, 35)

# %%
newtest.shape
# Out:
# (97, 30)

# %%
df1_train = pd.DataFrame(train, columns= ['Date', 'Open-Stock-1', 'High-Stock-1', 'Low-Stock-1', 'VWAP-Stock-1', 'Volume-Stock-1', 'Turnover-Stock-1','Close-Stock-1'])

# %%
df1_train = df1_train.set_index('Date')
df1_train.head()
# Out:
#             Open-Stock-1  High-Stock-1  Low-Stock-1  VWAP-Stock-1  \
# Date
# 2010-06-01        1889.7       1890.00      1838.00       1855.75
# 2010-06-02        1848.0       1862.75      1828.00       1842.82
# 2010-06-03        1864.1       1910.00      1864.10       1893.91
# 2010-06-04        1906.0       1909.80      1880.10       1889.21
# 2010-06-07        1867.0       1894.85      1808.35       1873.32
#
#             Volume-Stock-1  Turnover-Stock-1  Close-Stock-1
# Date
# 2010-06-01          568273   105457457545000        1855.10
# 2010-06-02          945167   174177161135000        1853.05
# 2010-06-03          679689   128727119355000        1905.60
# 2010-06-04          509435    96242800140000        1885.70
# 2010-06-07          961913   180196832650000        1876.65

# %%
df2_train = pd.DataFrame(train, columns= ['Date', 'Open-Stock-2', 'High-Stock-2', 'Low-Stock-2', 'VWAP-Stock-2', 'Volume-Stock-2', 'Turnover-Stock-2', 'Close-Stock-2'])
df2_train = df2_train.set_index('Date')
df2_train.head()
# Out:
#             Open-Stock-2  High-Stock-2  Low-Stock-2  VWAP-Stock-2  \
# Date
# 2010-06-01        285.40        285.95       281.50        283.72
# 2010-06-02        284.00        284.80       279.25        281.05
# 2010-06-03        283.00        286.85       282.50        285.34
# 2010-06-04        288.85        291.80       277.00        289.81
# 2010-06-07        285.00        289.10       285.00        287.01
#
#             Volume-Stock-2  Turnover-Stock-2  Close-Stock-2
# Date
# 2010-06-01         3191773    90557243170000         283.00
# 2010-06-02         2704797    76017076445000         281.30
# 2010-06-03         2489752    71043460510000         285.50
# 2010-06-04         3188813    92414802585000         290.85
# 2010-06-07         2198836    63109395135000         287.70

# %%
df3_train = pd.DataFrame(train, columns= ['Date', 'Open-Stock-3', 'High-Stock-3', 'Low-Stock-3', 'VWAP-Stock-3', 'Volume-Stock-3', 'Turnover-Stock-3', 'Close-Stock-3'])
df3_train = df3_train.set_index('Date')
df3_train.head()
# Out:
#             Open-Stock-3  High-Stock-3  Low-Stock-3  VWAP-Stock-3  \
# Date
# 2010-06-01       2095.00        2097.8      2045.00       2088.95
# 2010-06-02       2061.45        2098.0      2023.00       2059.52
# 2010-06-03       2131.50        2131.5      2091.05       2107.84
# 2010-06-04       2114.90        2156.0      2095.50       2145.36
# 2010-06-07       2132.35        2209.0      2112.00       2180.52
#
#             Volume-Stock-3  Turnover-Stock-3  Close-Stock-3
# Date
# 2010-06-01           70547    14736933230000        2077.25
# 2010-06-02           55547    11440017990000        2079.85
# 2010-06-03           55130    11620529360000        2114.90
# 2010-06-04           29302     6286330280000        2146.75
# 2010-06-07           78919    17208425860000        2185.25

# %%
df4_train = pd.DataFrame(train, columns= ['Date', 'Open-Stock-4', 'High-Stock-4', 'Low-Stock-4', 'VWAP-Stock-4', 'Volume-Stock-4', 'Turnover-Stock-4', 'Close-Stock-4'])
df4_train = df4_train.set_index('Date')
df4_train.head()
# Out:
#             Open-Stock-4  High-Stock-4  Low-Stock-4  VWAP-Stock-4  \
# Date
# 2010-06-01        851.65        864.80        833.1        844.44
# 2010-06-02        844.70        849.90        823.0        838.31
# 2010-06-03        851.40        859.05        848.2        853.51
# 2010-06-04        854.10        868.60        854.1        862.85
# 2010-06-07        712.00        850.00        712.0        839.89
#
#             Volume-Stock-4  Turnover-Stock-4  Close-Stock-4
# Date
# 2010-06-01         3878011   327474904340000         837.95
# 2010-06-02         3320996   278403743240000         842.30
# 2010-06-03         2494522   212910342645000         854.10
# 2010-06-04         2963920   255740999120000         865.85
# 2010-06-07         3471483   291567400640000         841.95

# %%
df5_train = pd.DataFrame(train, columns= ['Date', 'Open-Stock-5', 'High-Stock-5', 'Low-Stock-5', 'VWAP-Stock-5', 'Volume-Stock-5', 'Turnover-Stock-5', 'Close-Stock-5'])
df5_train = df5_train.set_index('Date')
df5_train.head()
# Out:
#             Open-Stock-5  High-Stock-5  Low-Stock-5  VWAP-Stock-5  \
# Date
# 2010-06-01        1235.0       1238.00       1177.0       1197.29
# 2010-06-02        1195.0       1206.95       1168.5       1189.87
# 2010-06-03        1211.0       1248.00       1211.0       1231.63
# 2010-06-04        1240.0       1258.00       1240.0       1249.72
# 2010-06-07        1218.6       1225.00       1196.0       1209.27
#
#             Volume-Stock-5  Turnover-Stock-5  Close-Stock-5
# Date
# 2010-06-01         1786082   213845404410000        1181.70
# 2010-06-02         1307410   155564994855000        1201.15
# 2010-06-03         1482919   182640434320000        1242.30
# 2010-06-04         1454459   181767075850000        1245.45
# 2010-06-07         1424594   172272511430000        1214.80

# %%
df1_test = pd.DataFrame(test, columns= ['Date', 'Open-Stock-1', 'High-Stock-1', 'Low-Stock-1', 'VWAP-Stock-1', 'Volume-Stock-1', 'Turnover-Stock-1'])
df1_test = df1_test.set_index('Date')
df1_test.head()
# Out:
#             Open-Stock-1  High-Stock-1  Low-Stock-1  VWAP-Stock-1  \
# Date
# 2011-08-04         484.1        488.90       475.00        481.00
# 2011-08-05         465.0        475.80       457.10        469.56
# 2011-08-08         463.0        480.00       458.05        465.04
# 2011-08-09         450.0        473.55       449.85        460.88
# 2011-08-10         494.8        494.80       473.40        478.06
#
#             Volume-Stock-1  Turnover-Stock-1
# Date
# 2011-08-04         1829606    88003633160000
# 2011-08-05         3156094   148196817355000
# 2011-08-08         4308373   200357861965000
# 2011-08-09         4490924   206978212685000
# 2011-08-10         3267226   156192368225000

# %%
df2_test = pd.DataFrame(test, columns= ['Date', 'Open-Stock-2', 'High-Stock-2', 'Low-Stock-2', 'VWAP-Stock-2', 'Volume-Stock-2', 'Turnover-Stock-2'])
df2_test = df2_test.set_index('Date')
df2_test.head()
# Out:
#             Open-Stock-2  High-Stock-2  Low-Stock-2  VWAP-Stock-2  \
# Date
# 2011-08-04        204.90        206.75       199.20        202.98
# 2011-08-05        195.00        198.00       190.50        194.86
# 2011-08-08        193.90        197.80       189.65        194.89
# 2011-08-09        190.25        202.10       190.10        197.61
# 2011-08-10        202.00        202.85       196.00        199.07
#
#             Volume-Stock-2  Turnover-Stock-2
# Date
# 2011-08-04        10501999   213174133870000
# 2011-08-05        13424736   261588793565000
# 2011-08-08         9002509   175445729750000
# 2011-08-09        19202643   379464261110000
# 2011-08-10         9274996   184640866420000

# %%
df3_test = pd.DataFrame(test, columns= ['Date', 'Open-Stock-3', 'High-Stock-3', 'Low-Stock-3', 'VWAP-Stock-3', 'Volume-Stock-3', 'Turnover-Stock-3'])
df3_test = df3_test.set_index('Date')
df3_test.head()
# Out:
#             Open-Stock-3  High-Stock-3  Low-Stock-3  VWAP-Stock-3  \
# Date
# 2011-08-04       3011.15       3119.95      3011.15       3078.97
# 2011-08-05       3091.65       3095.00      3012.00       3061.60
# 2011-08-08       3015.05       3109.00      3010.00       3069.09
# 2011-08-09       3070.00       3164.00      2988.00       3113.84
# 2011-08-10       3125.00       3195.00      3125.00       3170.39
#
#             Volume-Stock-3  Turnover-Stock-3
# Date
# 2011-08-04           53783    16559616060000
# 2011-08-05          129372    39608524605000
# 2011-08-08           46725    14340318455000
# 2011-08-09           88749    27635029505000
# 2011-08-10           52720    16714302965000

# %%
df4_test = pd.DataFrame(test, columns= ['Date', 'Open-Stock-4', 'High-Stock-4', 'Low-Stock-4', 'VWAP-Stock-4', 'Volume-Stock-4', 'Turnover-Stock-4'])
df4_test = df4_test.set_index('Date')
df4_test.head()
# Out:
#             Open-Stock-4  High-Stock-4  Low-Stock-4  VWAP-Stock-4  \
# Date
# 2011-08-04       1008.50        1015.0       990.00       1003.31
# 2011-08-05        970.00         979.7       950.00        961.50
# 2011-08-08        940.05         975.0       933.40        953.24
# 2011-08-09        915.00         967.6       910.45        938.80
# 2011-08-10        963.95         971.2       957.70        964.75
#
#             Volume-Stock-4  Turnover-Stock-4
# Date
# 2011-08-04         2716435   272542181190000
# 2011-08-05         4644498   446567961345000
# 2011-08-08         3450619   328925252905000
# 2011-08-09         5346085   501890604795000
# 2011-08-10         3379659   326053305165000

# %%
df5_test = pd.DataFrame(test, columns= ['Date', 'Open-Stock-5', 'High-Stock-5', 'Low-Stock-5', 'VWAP-Stock-5', 'Volume-Stock-5', 'Turnover-Stock-5'])
df5_test = df5_test.set_index('Date')
df5_test.head()
# Out:
#             Open-Stock-5  High-Stock-5  Low-Stock-5  VWAP-Stock-5  \
# Date
# 2011-08-04        1303.6        1312.8      1281.00       1297.04
# 2011-08-05        1245.0        1252.5      1200.00       1229.09
# 2011-08-08        1205.2        1265.8      1200.55       1232.93
# 2011-08-09        1190.5        1238.3      1180.90       1206.06
# 2011-08-10        1242.0        1253.7      1225.30       1242.10
#
#             Volume-Stock-5  Turnover-Stock-5
# Date
# 2011-08-04         1569675   203593328285000
# 2011-08-05         3125692   384176649890000
# 2011-08-08         1660178   204687918340000
# 2011-08-09         3618186   436376441205000
# 2011-08-10         1903396   236421421150000

# %%
df1_train.head()
# Out:
#             Open-Stock-1  High-Stock-1  Low-Stock-1  VWAP-Stock-1  \
# Date
# 2010-06-01        1889.7       1890.00      1838.00       1855.75
# 2010-06-02        1848.0       1862.75      1828.00       1842.82
# 2010-06-03        1864.1       1910.00      1864.10       1893.91
# 2010-06-04        1906.0       1909.80      1880.10       1889.21
# 2010-06-07        1867.0       1894.85      1808.35       1873.32
#
#             Volume-Stock-1  Turnover-Stock-1  Close-Stock-1
# Date
# 2010-06-01          568273   105457457545000        1855.10
# 2010-06-02          945167   174177161135000        1853.05
# 2010-06-03          679689   128727119355000        1905.60
# 2010-06-04          509435    96242800140000        1885.70
# 2010-06-07          961913   180196832650000        1876.65

# %%
df1_train.tail()
# Out:
#             Open-Stock-1  High-Stock-1  Low-Stock-1  VWAP-Stock-1  \
# Date
# 2011-07-28        499.50        499.50        484.6        489.79
# 2011-07-29        489.90        489.90        481.1        485.65
# 2011-08-01        493.45        495.95        484.5        489.14
# 2011-08-02        487.90        487.90        480.0        483.30
# 2011-08-03        478.70        489.40        476.0        481.89
#
#             Volume-Stock-1  Turnover-Stock-1  Close-Stock-1
# Date
# 2011-07-28         5354489   262255417380000         487.30
# 2011-07-29         2997667   145582296035000         486.80
# 2011-08-01         2202354   107726909450000         488.00
# 2011-08-02         1982494    95814144795000         482.85
# 2011-08-03         2082567   100357122620000         482.05

# %%
train1 = df1_train.iloc[0:240,:]
test1 = df1_train.iloc[240: , :]

# %%
train1.shape
# Out:
# (240, 7)

# %%
test1.shape
# Out:
# (59, 7)

# %%
x = df1_train.drop('Close-Stock-1', axis = 1)
y = df1_train['Close-Stock-1']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
scaler = MinMaxScaler(feature_range=(0, 1))
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(x_train, y_train, epochs=3, batch_size=100, validation_data=(x_test, y_test), verbose=0, shuffle=False)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print('Test RMSE: %.3f' % rmse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-691cf774003d> in <module>
# ----> 1 rmse = np.sqrt(mean_squared_error(y_test, y_pred))
#       2 print('Test RMSE: %.3f' % rmse)
#
# NameError: name 'y_pred' is not defined

# %%
y_pred = model.predict(x_test)
plt.plot(y_pred, label='predict')
plt.plot(y_test, label='true')
plt.legend()
plt.show()

# %%
x = df1_train.drop('Close-Stock-1', axis = 1)
y = df1_train['Close-Stock-1']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %% [raw]
# 1st June 2010 to 3rd August 2011

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM

#creating dataframe
data = df.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])
for i in range(0,len(data)):
    new_data['Date'][i] = data['Date'][i]
    new_data['Close'][i] = data['Close'][i]

#setting index
new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)

#creating train and test sets
dataset = new_data.values

train = dataset[0:987,:]
valid = dataset[987:,:]

#converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# create and fit the LSTM network
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=50))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=1, batch_size=1, verbose=2)

#predicting 246 values, using past 60 from the train data
inputs = new_data[len(new_data) - len(valid) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)

# %%
df1_train = pd.DataFrame(train, columns= ['Date', 'VWAP-Stock-1', 'Close-Stock-1'])

# %%
df1_train = df1_train.set_index('Date')
df1_train.head()
# Out:
#             VWAP-Stock-1  Close-Stock-1
# Date
# 2010-06-01       1855.75        1855.10
# 2010-06-02       1842.82        1853.05
# 2010-06-03       1893.91        1905.60
# 2010-06-04       1889.21        1885.70
# 2010-06-07       1873.32        1876.65

# %%
df2_train = pd.DataFrame(train, columns= ['Date','VWAP-Stock-2', 'Close-Stock-2'])
df2_train = df2_train.set_index('Date')
df2_train.head()
# Out:
#             VWAP-Stock-2  Close-Stock-2
# Date
# 2010-06-01        283.72         283.00
# 2010-06-02        281.05         281.30
# 2010-06-03        285.34         285.50
# 2010-06-04        289.81         290.85
# 2010-06-07        287.01         287.70

# %%
df3_train = pd.DataFrame(train, columns= ['Date',  'VWAP-Stock-3', 'Close-Stock-3'])
df3_train = df3_train.set_index('Date')
df3_train.head()
# Out:
#             VWAP-Stock-3  Close-Stock-3
# Date
# 2010-06-01       2088.95        2077.25
# 2010-06-02       2059.52        2079.85
# 2010-06-03       2107.84        2114.90
# 2010-06-04       2145.36        2146.75
# 2010-06-07       2180.52        2185.25

# %%
df4_train = pd.DataFrame(train, columns= ['Date', 'VWAP-Stock-4', 'Close-Stock-4'])
df4_train = df4_train.set_index('Date')
df4_train.head()
# Out:
#             VWAP-Stock-4  Close-Stock-4
# Date
# 2010-06-01        844.44         837.95
# 2010-06-02        838.31         842.30
# 2010-06-03        853.51         854.10
# 2010-06-04        862.85         865.85
# 2010-06-07        839.89         841.95

# %%
df5_train = pd.DataFrame(train, columns= ['Date', 'VWAP-Stock-5', 'Close-Stock-5'])
df5_train = df5_train.set_index('Date')
df5_train.head()
# Out:
#             VWAP-Stock-5  Close-Stock-5
# Date
# 2010-06-01       1197.29        1181.70
# 2010-06-02       1189.87        1201.15
# 2010-06-03       1231.63        1242.30
# 2010-06-04       1249.72        1245.45
# 2010-06-07       1209.27        1214.80

# %%
df1_test = pd.DataFrame(test, columns= ['Date',  'VWAP-Stock-1'])
df1_test = df1_test.set_index('Date')
df1_test.head()
# Out:
#             VWAP-Stock-1
# Date
# 2011-08-04        481.00
# 2011-08-05        469.56
# 2011-08-08        465.04
# 2011-08-09        460.88
# 2011-08-10        478.06

# %%
df2_test = pd.DataFrame(test, columns= ['Date', 'VWAP-Stock-2'])
df2_test = df2_test.set_index('Date')
df2_test.head()
# Out:
#             VWAP-Stock-2
# Date
# 2011-08-04        202.98
# 2011-08-05        194.86
# 2011-08-08        194.89
# 2011-08-09        197.61
# 2011-08-10        199.07

# %%
df3_test = pd.DataFrame(test, columns= ['Date',  'VWAP-Stock-3'])
df3_test = df3_test.set_index('Date')
df3_test.head()
# Out:
#             VWAP-Stock-3
# Date
# 2011-08-04       3078.97
# 2011-08-05       3061.60
# 2011-08-08       3069.09
# 2011-08-09       3113.84
# 2011-08-10       3170.39

# %%
df4_test = pd.DataFrame(test, columns= ['Date',  'VWAP-Stock-4'])
df4_test = df4_test.set_index('Date')
df4_test.head()
# Out:
#             VWAP-Stock-4
# Date
# 2011-08-04       1003.31
# 2011-08-05        961.50
# 2011-08-08        953.24
# 2011-08-09        938.80
# 2011-08-10        964.75

# %%
df5_test = pd.DataFrame(test, columns= ['Date',  'VWAP-Stock-5'])
df5_test = df5_test.set_index('Date')
df5_test.head()
# Out:
#             VWAP-Stock-5
# Date
# 2011-08-04       1297.04
# 2011-08-05       1229.09
# 2011-08-08       1232.93
# 2011-08-09       1206.06
# 2011-08-10       1242.10

# %%
x = df1_train.drop('Close-Stock-1', axis = 1)
y = df1_train['Close-Stock-1']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
y_pred1 = rf.fit(x_train, y_train).predict(x_test)

from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test, y_pred1))
# Out:
# 15.658083600944419

# %%
x_train = df1_train.drop('Close-Stock-1', axis = 1)
y_train = df1_train['Close-Stock-1']
x_test = df1_test
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
y_pred1 = rf.fit(x_train, y_train).predict(x_test)

# %%
x = df2_train.drop('Close-Stock-2', axis = 1)
y = df2_train['Close-Stock-2']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
y_pred2 = rf.fit(x_train, y_train).predict(x_test)

np.sqrt(mean_squared_error(y_test, y_pred2))
# Out:
# 1.3774393488493017

# %%
x_train = df2_train.drop('Close-Stock-2', axis = 1)
y_train = df2_train['Close-Stock-2']
x_test = df2_test
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
y_pred2 = rf.fit(x_train, y_train).predict(x_test)

# %%
x = df3_train.drop('Close-Stock-3', axis = 1)
y = df3_train['Close-Stock-3']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
y_pred3 = rf.fit(x_train, y_train).predict(x_test)

np.sqrt(mean_squared_error(y_test, y_pred3))
# Out:
# 22.832134505907614

# %%
x_train = df3_train.drop('Close-Stock-3', axis = 1)
y_train = df3_train['Close-Stock-3']
x_test = df3_test
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
y_pred3 = rf.fit(x_train, y_train).predict(x_test)

# %%
x = df4_train.drop('Close-Stock-4', axis = 1)
y = df4_train['Close-Stock-4']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
y_pred4 = rf.fit(x_train, y_train).predict(x_test)

np.sqrt(mean_squared_error(y_test, y_pred4))
# Out:
# 9.413780398040055

# %%
x_train = df4_train.drop('Close-Stock-4', axis = 1)
y_train = df4_train['Close-Stock-4']
x_test = df4_test
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
y_pred4 = rf.fit(x_train, y_train).predict(x_test)

# %%
x = df5_train.drop('Close-Stock-5', axis = 1)
y = df5_train['Close-Stock-5']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
y_pred5 = rf.fit(x_train, y_train).predict(x_test)

np.sqrt(mean_squared_error(y_test, y_pred5))
# Out:
# 11.172093854406622

# %%
x_train = df5_train.drop('Close-Stock-5', axis = 1)
y_train = df5_train['Close-Stock-5']
x_test = df5_test
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
y_pred5 = rf.fit(x_train, y_train).predict(x_test)

# %%
solution = pd.DataFrame({'Date': test.Date, 'Close-Stock-1': np.round(y_pred1,2), 'Close-Stock-2': np.round(y_pred2,2), 
                        'Close-Stock-3' : np.round(y_pred3,2), 'Close-Stock-4': np.round(y_pred4,2), 'Close-Stock-5': np.round(y_pred5,2)})
solution.to_csv('Solution.csv', index = False)
